# %% [markdown]
# # Análise de resíduos
# Índice <a name="topo"></a>
#
# 1. [Padrão esperado de resíduos](#1)
# 2. [Padrão côncavo](#2)
# 3. [Padrão convexo](#3)
# 4. [Padrão de variância crescente](#4)
# 5. [Transformações em x](#5)
# 6. [Transformação na variável resposta](#6)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

import statsmodels.formula.api as smf
# %matplotlib inline
plt.rc('figure', figsize=(6, 4))

# %% [markdown]
# ### 1. Padrão esperado de resíduos<a name="1"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#topo)

# %%
df = pd.DataFrame({'y':np.random.randn(200), 'x':np.arange(0, 1, .005)})

sns.scatterplot(x = 'x', y = 'y', data = df, alpha = .75)
plt.axhline(y=0, color='r', linestyle='--')

# %% [markdown]
# ### 2. Padrão côncavo<a name="2"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#topo)

# %%
df['y'] = np.exp(2.5*(df['x']-(df['x'].min()-.1))) + np.random.randn(200)*.1
df['y'] = df['y'] - df['y'].mean()

reg = smf.ols('y ~ x', data = df).fit()
df['res'] = reg.resid

sns.scatterplot(x='x', y='res', data=df, alpha = .75)
plt.axhline(y=0, color='r', linestyle='--')

# %%
sns.regplot(x='x', y='y', data=df)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### 3. Padrão convexo<a name="3"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#topo)

# %%
df['y'] = np.log((df['x']-(df['x'].min()-.1))) + np.random.randn(200)*.05
df['y'] = df['y'] - df['y'].mean()

reg = smf.ols('y ~ x', data=df).fit()
df['res'] = reg.resid

sns.scatterplot(x='x', y='res', data=df, alpha=.75)
plt.axhline(y=0, color='r', linestyle='--')

# %%
sns.regplot(x='x', y='y', data=df)
plt.plot(df['x'], reg.fittedvalues, 'r,--')

# %% [markdown]
# ### 4. Padrão de variância crescente<a name="4"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#topo)

# %%
df['y'] = 5*(df['x']-(df['x'].min()-.1)) + (df['x']-(df['x'].min()-.1))*np.random.randn(200)*1.5

reg = smf.ols('y ~ x', data=df).fit()
df['res'] = reg.resid

sns.scatterplot(x='x', y='res', data=df, alpha=.75)
plt.axhline(y=0, color='r', linestyle='--')

# %%
sns.regplot(x='x', y='y', data=df)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### 5. Transformações em x<a name="5"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#topo)</div>
#
# Uma forma de buscar um melhor ajuste em uma regressão com padrão de relação não linear entre x e y é buscar uma função g(x) que linearize essa relação. Dentre as opções, podemos tentar:
# - categorizar x
# - ajustar um polinômio
# - transformar por uma função log, exponencial, raiz etc.

# %%
df['y'] = np.log((df['x']-(df['x'].min()-.1))) + np.random.randn(200)*.05
df['y'] = df['y'] - df['y'].mean()
sns.regplot(x='x', y='y', data=df)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# A regressão com a variável ```x``` "crua" resulta em padrâo convexo nos resíduos

# %%
reg = smf.ols('y ~ x', data=df).fit()
print(reg.summary())
df['res'] = reg.resid

sns.scatterplot(x='x', y='res', data=df, alpha=.75)
plt.axhline(y=0, color='r', linestyle='--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     2076.
# Date:                Fri, 23 Aug 2024   Prob (F-statistic):          6.53e-107
# Time:                        14:14:11   Log-Likelihood:                 58.603
# No. Observations:                 200   AIC:                            -113.2
# Df Residuals:                     198   BIC:                            -106.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0074      0.026    -39.412      0.000      -1.058      -0.957
# x              2.0250      0.044     45.566      0.000       1.937       2.113
# ==============================================================================
# Omnibus:                       34.003   Durbin-Watson:                   0.146
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.888
# Skew:                          -1.060   Prob(JB):                     1.09e-10
# Kurtosis:                       4.004   Cond. No.                         4.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Ajustando um polinômio de segundo grau

# %%
reg = smf.ols('y ~ x + np.power(x,2)', data=df).fit()
print(reg.summary())
df['res'] = reg.resid

sns.scatterplot(x='x', y='res', data=df, alpha=.75)
plt.axhline(y=0, color='r', linestyle='--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     5732.
# Date:                Fri, 23 Aug 2024   Prob (F-statistic):          2.69e-175
# Time:                        14:14:40   Log-Likelihood:                 222.57
# No. Observations:                 200   AIC:                            -439.1
# Df Residuals:                     197   BIC:                            -429.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -1.3644      0.017    -81.081      0.000      -1.398      -1.331
# x                  4.1884      0.078     53.603      0.000       4.034       4.343
# np.power(x, 2)    -2.1743      0.076    -28.605      0.000      -2.324      -2.024
# ==============================================================================
# Omnibus:                       13.137   Durbin-Watson:                   0.743
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.038
# Skew:                          -0.518   Prob(JB):                     0.000543
# Kurtosis:                       3.856   Cond. No.                         22.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.regplot(x='x', y='y', data=df)
plt.plot(df['x'], reg.fittedvalues, 'r,--')

# %% [markdown]
# #### Ajustando uma função exponencial

# %%
reg = smf.ols('y ~ np.exp(x)', data=df).fit()
print(reg.summary())
df['res'] = reg.resid

sns.scatterplot(x='x', y='res', data=df, alpha=.75)
plt.axhline(y=0, color='r', linestyle='--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     1018.
# Date:                Fri, 23 Aug 2024   Prob (F-statistic):           5.69e-80
# Time:                        14:15:29   Log-Likelihood:                -4.0132
# No. Observations:                 200   AIC:                             12.03
# Df Residuals:                     198   BIC:                             18.62
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.9551      0.064    -30.672      0.000      -2.081      -1.829
# np.exp(x)      1.1407      0.036     31.905      0.000       1.070       1.211
# ==============================================================================
# Omnibus:                       33.520   Durbin-Watson:                   0.079
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.497
# Skew:                          -1.094   Prob(JB):                     2.18e-10
# Kurtosis:                       3.746   Cond. No.                         8.40
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.regplot(x='x', y='y', data=df)
plt.plot(df['x'], reg.fittedvalues, 'r,--')

# %% [markdown]
# #### Ajustando uma função logaritmica

# %%
reg = smf.ols('y ~ np.log(x+.1)', data=df).fit()
print(reg.summary())
df['res'] = reg.resid

sns.scatterplot(x='x', y='res', data=df, alpha=.75)
plt.axhline(y=0, color='r', linestyle='--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                 3.118e+04
# Date:                Fri, 23 Aug 2024   Prob (F-statistic):          8.95e-220
# Time:                        14:16:15   Log-Likelihood:                 321.06
# No. Observations:                 200   AIC:                            -638.1
# Df Residuals:                     198   BIC:                            -631.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.6701      0.005    130.604      0.000       0.660       0.680
# np.log(x + .1)     0.9988      0.006    176.592      0.000       0.988       1.010
# ==============================================================================
# Omnibus:                        3.171   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.205   Jarque-Bera (JB):                3.166
# Skew:                          -0.268   Prob(JB):                        0.205
# Kurtosis:                       2.694   Cond. No.                         2.60
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.regplot(x='x', y='y', data=df)
plt.plot(df['x'], reg.fittedvalues, 'r,--')

# %% [markdown]
# ### 6. Transformação na variável resposta<a name="6"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#topo)

# %%
x = np.arange(0,1,.001)
df = pd.DataFrame({'y':np.exp(x + np.random.randn(1000)*.08), 'x':x})

sns.regplot(x='x', y='y', data=df)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
reg = smf.ols('y ~ x', data=df).fit()
print(reg.summary())
df['res'] = reg.resid

sns.scatterplot(x='x', y='res', data=df, alpha=.75)
plt.axhline(y=0, color='r', linestyle='--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     9595.
# Date:                Fri, 23 Aug 2024   Prob (F-statistic):               0.00
# Time:                        18:11:29   Log-Likelihood:                 416.11
# No. Observations:                1000   AIC:                            -828.2
# Df Residuals:                     998   BIC:                            -818.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8715      0.010     86.315      0.000       0.852       0.891
# x              1.7143      0.018     97.954      0.000       1.680       1.749
# ==============================================================================
# Omnibus:                       26.191   Durbin-Watson:                   1.655
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.438
# Skew:                           0.332   Prob(JB):                     2.46e-07
# Kurtosis:                       3.539   Cond. No.                         4.39
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outra forma de calcular o R^2
df['pred'] = reg.fittedvalues

r = df[['pred', 'y']].corr().iloc[0,1]

# %%
r**2
# Out:
# 0.90578717459903

# %% [markdown]
# #### Log na variável resposta usando o Patsy

# %%
reg = smf.ols('np.log(y) ~ x', data=df).fit()
print(reg.summary())
df['res'] = reg.resid

sns.scatterplot(x='x', y='res', data=df, alpha=.75)
plt.axhline(y=0, color='r', linestyle='--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              np.log(y)   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                 1.291e+04
# Date:                Fri, 23 Aug 2024   Prob (F-statistic):               0.00
# Time:                        18:12:07   Log-Likelihood:                 1094.4
# No. Observations:                1000   AIC:                            -2185.
# Df Residuals:                     998   BIC:                            -2175.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0026      0.005     -0.508      0.611      -0.013       0.007
# x              1.0092      0.009    113.632      0.000       0.992       1.027
# ==============================================================================
# Omnibus:                        0.193   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.908   Jarque-Bera (JB):                0.266
# Skew:                          -0.021   Prob(JB):                        0.876
# Kurtosis:                       2.932   Cond. No.                         4.39
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Por que não posso comparar o R^2 desse modelo com o primeiro?

# %%
sns.regplot(x='x', y='y', data=df)
plt.plot(df['x'], reg.fittedvalues, 'r,--')

# %% [markdown]
# #### Então como eu calculo o R^2 no dado original?

# %%
df['pred_y'] = np.exp(reg.fittedvalues)

df[['pred_y', 'y']].corr().iloc[0,1]**2
# Out:
# 0.9204974917019632

# %%
sns.regplot(x='x', y='y', data=df)
plt.plot(df['x'], df['pred_y'], 'r,--')
