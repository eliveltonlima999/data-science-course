# %% [markdown]
# # Módulo 6 Aula 2

# %% [markdown]
# # Introdução ao Matplotlib
# Além de o matplotlib ser o pacote mais popular para construção de gráficos no Python, ele é a base dos métodos gráficos do pandas e também dos gráficos feitos pelo seaborne - que é uma biblioteca que fornece procedimentos práticos para a construção de gráficos mais sofisticados,

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline (Não funciona em todos os gráficos)
# %matplotlib notebook (NÃO FUNCIONA)
# %matplotlib ipympl
# %matplotlib widget (Não funciona em todos os gráficos)

# %%
data = [1,2,3,3,2,3,4,5]

plt.plot(data)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Cria uma figura em branco
fig = plt.figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Adiciona um gráfico na figura. add_subplot(estrutura, estrutura, posição)
ax1 = fig.add_subplot(2,2,1)

# %%
type(ax1)
# Out:
# matplotlib.axes._axes.Axes

# %%
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
# Parametro estetico 'k--', linha traçada na cor preta
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
# Parametro estetico 'alpha=.3', transparencia
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=.3)
_ = ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %% [markdown]
# Você encontra o catálogo completo dos tipos de plotagem na [documentação](https://matplotlib.org/) do matplotlib, ou através do <shift + TAB> na função.

# %%
# Fecha todos os gráficos abertos
plt.close('all')

# %%
# Adiciona os gráficos em uma grade 2x3
fig, axes = plt.subplots(2, 3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
axes[0,0]
# axes.shape
# Out:
# <Axes: >

# %% [markdown]
# ### Espaçamento em torno das subplotagens

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='b', alpha=0.9)
        
# O método subplots_adjust ajusta o espaçamento entre os eixos.
plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Cores, marcadores e estilo de linha
# ax.plot(x, y, 'g--')
#
# ax.plot(x, y, linestyle='--', color='g')

# %%
# Fecha todos as figuras abertas
plt.close('all')

# %%
# Cria uma nova figura em branco
fig = plt.figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from numpy.random import randn

# Gera gráfico de linha pontilhado com bolinha na cor verde, parametro estetico 'go--'.
plt.plot(randn(30).cumsum(), 'go--')

# %%
# Fecha todas as figuras abertas
plt.close('all')

# %%
# Ver documentação
# plt.plot?

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'b-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Tiques, rótulos e legendas

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
# Altera as labels, rotacao e tamanho
labels = ax.set_xticklabels(['ano 1', 'ano 2', 'ano 3', 'ano 4', 'ano 5'],
                            rotation=30, fontsize='small')

# %%
# Altera o titulo e rotulo do eixo x
ax.set_title('Título do gráfico')
ax.set_xlabel('Período')
# Out:
# Text(0.5, 9.951391973024522, 'Período')

# %% [markdown]
# #### adicionando legendas

# %%
plt.close('all')
from numpy.random import randn
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Adiciona a legenda na melhor posição da figura
ax.legend(loc='best')

# %% [markdown]
# # Salvando em arquivos

# %% [markdown]
# plt.savefig('figpath.svg')
#
# plt.savefig('figpath.png', dpi=400, bbox_inches='tight')
#
# from io import BytesIO buffer = BytesIO() plt.savefig(buffer) plot_data = buffer.getvalue()

# %%
plt.savefig('figura.jpg')

# %% [markdown]
# # Configuração do Matplotlib

# %% [markdown]
# plt.rc('figure', figsize=(10, 10))
#
# font_options = {'family' : 'monospace', 'weight' : 'bold', 'size' : 'small'} plt.rc('font', **font_options)
