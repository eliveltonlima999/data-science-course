# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
# Definindo a url da api
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Município'
# Realizando requisição
r = requests.get(url)
# Verificando se ocorreu tudo certo
r.status_code
# Pegando o json
data_json = r.json()
# Armazenando no dataframe
df_pvl = pd.DataFrame(data_json['items'])
df_pvl

df_pvl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              260 non-null    int64
#  1   tipo_interessado       260 non-null    object
#  2   interessado            260 non-null    object
#  3   cod_ibge               260 non-null    int64
#  4   uf                     260 non-null    object
#  5   num_pvl                83 non-null     object
#  6   status                 260 non-null    object
#  7   num_processo           235 non-null    object
#  8   data_protocolo         235 non-null    object
#  9   tipo_operacao          260 non-null    object
#  10  finalidade             260 non-null    object
#  11  tipo_credor            260 non-null    object
#  12  credor                 260 non-null    object
#  13  moeda                  260 non-null    object
# ...

# %%
# 2) Seu código aqui
df_pvl.status.value_counts()
# Out:
# status
# Deferido                                                 106
# Arquivado                                                 53
# Regularizado                                              26
# Deferido (PVL-IF)                                         24
# Arquivado por decurso de prazo                            24
# Encaminhado à PGFN com manifestação técnica favorável     14
# Arquivado a pedido                                         8
# Em retificação pelo interessado                            3
# Arquivado a pedido (PVL-IF)                                1
# Arquivado pela STN                                         1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
# Filtrando e indexando por status
data_status = df_pvl[['status','data_status']].set_index('status')
# data_status

# Transformando a coluna 'data_status' em string e formatando a data
new_list_data = data_status['data_status'].astype(str).apply(lambda data: data.split('/')[2])

# Transformando em dataframe para melhor visulização
df_new_list_data = pd.DataFrame(new_list_data)
df_new_list_data
# Out:
#                                data_status
# status
# Deferido (PVL-IF)                     2019
# Regularizado                          2007
# Arquivado                             2008
# Arquivado a pedido                    2023
# Deferido                              2011
# ...                                    ...
# Arquivado por decurso de prazo        2015
# Arquivado                             2010
# Deferido (PVL-IF)                     2019
# Arquivado pela STN                    2023
# Deferido                              2023
#
# [260 rows x 1 columns]

# %%
# 4) Seu código aqui
df_new_list_data.data_status.value_counts()
# Out:
# data_status
# 2008    37
# 2023    29
# 2007    29
# 2014    20
# 2010    19
# 2019    16
# 2013    15
# 2020    15
# 2012    13
# 2022    11
# 2011    10
# 2009     9
# 2015     8
# 2017     5
# 2021     5
# 2002     4
# 2018     4
# 2006     4
# 2016     4
# 2003     1
# 2024     1
# 2004     1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_pvl(uf, tipo):
    r = requests.get(('https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=%s&tipo_interessado=%s' % (uf, tipo)))
    data_json = r.json()
    return pd.DataFrame(data_json['items'])

consulta_pvl('AC', 'Estado')
# Out:
#     id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0        9461           Estado        Acre        12  AC
# 1       25091           Estado        Acre        12  AC
# 2        7974           Estado        Acre        12  AC
# 3        5901           Estado        Acre        12  AC
# 4        6885           Estado        Acre        12  AC
# 5       28324           Estado        Acre        12  AC
# 6       11301           Estado        Acre        12  AC
# 7       13321           Estado        Acre        12  AC
# 8       66210           Estado        Acre        12  AC
# 9       10055           Estado        Acre        12  AC
# 10      23724           Estado        Acre        12  AC
# 11       7967           Estado        Acre        12  AC
# 12      66219           Estado        Acre        12  AC
# 13       5904           Estado        Acre        12  AC
# 14      10732           Estado        Acre        12  AC
# ...

# %%
# 2) Seu código aqui
pvl_mg = consulta_pvl('MG', 'Estado')

pvl_mg.loc[pvl_mg['status'] == 'Arquivado por decurso de prazo', 'status'].count()
# Out:
# 1

# %%
# 3) Seu código aqui
pvl_ba = consulta_pvl('BA', 'Município')

pvl_ba_deferidos = pvl_ba.loc[pvl_ba['status'] == 'Deferido', ['status', 'interessado']]

pvl_ba_deferidos.rename(columns={'interessado': 'Municipio', 'status': 'Deferidos'}, inplace = True)

pvl_ba_deferidos.groupby(by=['Municipio']).count().sort_values(by='Deferidos', ascending=False)
# Out:
#                         Deferidos
# Municipio
# Luís Eduardo Magalhães         16
# Vitória da Conquista           12
# Lauro de Freitas               11
# Camaçari                       10
# Barreiras                      10
# ...                           ...
# Licínio de Almeida              1
# Lençóis                         1
# Juazeiro                        1
# Jeremoabo                       1
# Xique-Xique                     1
#
# [185 rows x 1 columns]

# %%
# 4) Seu código aqui
df_pvl_ba_for_csv = consulta_pvl('BA', 'Estado')
df_pvl_ba_for_csv.to_csv('df_pvl_ba.csv')
