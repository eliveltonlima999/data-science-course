# %%
import numpy  as np
import pandas as pd

# %% [markdown]
# # Operações com ``DataFrame``

# %% [markdown]
# ## Criando 2 dataframes (3 x 5)

# %%
np.random.randint(10, size=(3, 5))
# Out:
# array([[7, 2, 0, 8, 0],
#        [6, 4, 2, 6, 0],
#        [7, 0, 7, 8, 2]])

# %%
df1 = pd.DataFrame(np.random.randint(10, size=(3, 5)), columns=['A','B','C','D','E'])
df1
# Out:
#    A  B  C  D  E
# 0  5  5  4  5  9
# 1  8  7  6  0  7
# 2  9  3  0  7  4

# %%
df2 = pd.DataFrame(np.random.randint(10, size=(3, 5)), columns=['A','B','C','D','E'])
df2
# Out:
#    A  B  C  D  E
# 0  9  6  7  8  1
# 1  2  9  3  0  1
# 2  6  5  1  2  2

# %% [markdown]
# ## Somando 2 dataframes (3 x 5)

# %%
df1 + df2
# Out:
#     A   B   C   D   E
# 0  14  11  11  13  10
# 1  10  16   9   0   8
# 2  15   8   1   9   6

# %% [markdown]
# ## Criando 1 dataframe (1 x 5)

# %%
df3 = pd.DataFrame(np.random.randint(10, size=(1, 5)), columns=['A','B','C','D','E'])
df3
# Out:
#    A  B  C  D  E
# 0  1  0  4  2  1

# %% [markdown]
# ## Somando 2 dataframes (3 x 5 e 1 x 5)

# %%
df1 + df3
# Out:
#      A    B    C    D     E
# 0  6.0  5.0  8.0  7.0  10.0
# 1  NaN  NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN   NaN

# %% [markdown]
# ## Zerando uma linha

# %%
df1
# Out:
#    A  B  C  D  E
# 0  5  5  4  5  9
# 1  8  7  6  0  7
# 2  9  3  0  7  4

# %%
df1.iloc[0]
# Out:
# A    5
# B    5
# C    4
# D    5
# E    9
# Name: 0, dtype: int32

# %%
df1 - df1.iloc[0]
# Out:
#    A  B  C  D  E
# 0  0  0  0  0  0
# 1  3  2  2 -5 -2
# 2  4 -2 -4  2 -5

# %% [markdown]
# ## Operação com escalar

# %%
df1
# Out:
#    A  B  C  D  E
# 0  5  5  4  5  9
# 1  8  7  6  0  7
# 2  9  3  0  7  4

# %%
df1 * 100
# Out:
#      A    B    C    D    E
# 0  500  500  400  500  900
# 1  800  700  600    0  700
# 2  900  300    0  700  400

# %%
df1 * 100 + 200
# Out:
#       A    B    C    D     E
# 0   700  700  600  700  1100
# 1  1000  900  800  200   900
# 2  1100  500  200  900   600

# %% [markdown]
# ## Transpondo df

# %%
df1
# Out:
#    A  B  C  D  E
# 0  5  5  4  5  9
# 1  8  7  6  0  7
# 2  9  3  0  7  4

# %%
df1.T
# Out:
#    0  1  2
# A  5  8  9
# B  5  7  3
# C  4  6  0
# D  5  0  7
# E  9  7  4

# %% [markdown]
# ## Calculando exponencial dos valores

# %%
np.exp(df1)
# Out:
#              A            B           C            D            E
# 0   148.413159   148.413159   54.598150   148.413159  8103.083928
# 1  2980.957987  1096.633158  403.428793     1.000000  1096.633158
# 2  8103.083928    20.085537    1.000000  1096.633158    54.598150

# %% [markdown]
# # Registros de Vacinação COVID19 (Acre)
#
# link: https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao/resource/ef3bd0b8-b605-474b-9ae5-c97390c197a8

# %% [markdown]
# ## Lendo CSV

# %%
vacAcre = pd.read_csv(
    'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-37bd8f3f-ecd0-4967-aa48-d87fffc2da41.c000.csv',
    sep=';')
vacAcre
# Out:
#                                       document_id  \
# 0       ae60a3c3-b038-46ad-8bcc-b0fbb85591c0-i0b0
# 1       a185d13a-5619-41ab-9dcc-fc05c222c556-i0b0
# 2       ae4eb2f2-de1e-431d-b09d-b1d2a310eb7c-i0b0
# 3       a1ad2a49-e8d4-4c3d-99e4-dcf4d46e45f9-i0b0
# 4       dcf75e5a-fd0f-4cc6-bb98-36c958e156da-i0b0
# ...                                           ...
# 373697  9d68fb36-493d-438c-b062-7ce6b25da63f-i0b0
# 373698  9d7a7692-e167-49fe-a8a5-3c9da286f364-i0b0
# 373699  9daa9169-0a09-426c-affe-7d984470b2e4-i0b0
# 373700  9dc0dcdc-d17d-4b64-a83b-8d99bac8b3e4-i0b0
# 373701  9dc63a45-594b-438d-ba13-31e944cff1c4-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       edf77236d644ba7d0049cf916e5dfdec81910c06fadc69...               9
# 1       53a21b19090e69145108f97de5a72610db1b1383b99147...              11
# 2       ae5f5c4633ba030bc700f8f5410a01167a54b4ed740729...              43
# 3       ede2ec24eae3e257b9acb6c57f8651c60e0d016aeb8c00...              29
# 4       5aafa70333fc3942d6b51c6bd586cd64bec8103f44c0a5...              47
# ...                                                   ...             ...
# 373697  ab85ab96407768619dce5687131f9d8e54335c59e60812...              36
# 373698  c628c59c549c6786f9d50eca2a5e9b3dd95faa80b2ff4e...              16
# 373699  4257989a7d119f2ee927d223b6f672e73b1e000f13e180...              10
# 373700  04595202add83f95fd1d0ec9b73bfc09541cafb9b54e2c...              30
# 373701  da16389ac31453c3936d4dabe5133722aa1fa33560d894...              46
#
#        paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                   2011-08-31                          M
# 1                   2010-02-05                          F
# 2                   1978-04-22                          M
# 3                   1992-12-21                          M
# 4                   1974-04-16                          F
# ...                        ...                        ...
# 373697              1985-03-21                          M
# 373698              2005-07-06                          F
# 373699              2011-10-26                          M
# 373700              1991-06-15                          F
# 373701              1975-07-09                          F
#
#         paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                             3                  PARDA
# 1                             4                AMARELA
# 2                             4                AMARELA
# 3                             3                  PARDA
# 4                             4                AMARELA
# ...                         ...                    ...
# 373697                        3                  PARDA
# 373698                        1                 BRANCA
# 373699                        3                  PARDA
# 373700                        2                  PRETA
# 373701                        4                AMARELA
#
#         paciente_endereco_coIbgeMunicipio  paciente_endereco_coPais  \
# 0                                120040.0                      10.0
# 1                                120040.0                      10.0
# 2                                120040.0                      10.0
# 3                                120040.0                      10.0
# 4                                120035.0                      10.0
# ...                                   ...                       ...
# 373697                           120040.0                      10.0
# 373698                           120020.0                      10.0
# 373699                           120040.0                      10.0
# 373700                           120040.0                      10.0
# 373701                           120060.0                      10.0
#
#        paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                         RIO BRANCO  ...                     NaN
# 1                         RIO BRANCO  ...                     NaN
# 2                         RIO BRANCO  ...                    10.0
# 3                         RIO BRANCO  ...                     2.0
# 4               MARECHAL THAUMATURGO  ...                     6.0
# ...                              ...  ...                     ...
# 373697                    RIO BRANCO  ...                     2.0
# 373698               CRUZEIRO DO SUL  ...                   114.0
# 373699                    RIO BRANCO  ...                     NaN
# 373700                    RIO BRANCO  ...                     2.0
# 373701                      TARAUACA  ...                     2.0
#
#                    vacina_categoria_nome   vacina_lote  \
# 0                                    NaN        FP8290
# 1                                    NaN        FP8290
# 2            Trabalhadores de Transporte       ABW4731
# 3                           Faixa Etária    221VCD025W
# 4       Povos e Comunidades Tradicionais  212VCD001ZVB
# ...                                  ...           ...
# 373697                      Faixa Etária        FA9096
# 373698                            Outros        FF5107
# 373699                               NaN       210390A
# 373700                      Faixa Etária    214VCD056W
# 373701                      Faixa Etária        FH4750
#
#         vacina_fabricante_nome  vacina_fabricante_referencia  \
# 0       Pendente Identificação            Organization/28290
# 1       Pendente Identificação            Organization/28290
# 2                  ASTRAZENECA   Organization/00394544000851
# 3          ASTRAZENECA/FIOCRUZ                           149
# 4          ASTRAZENECA/FIOCRUZ   Organization/33781055000135
# ...                        ...                           ...
# 373697                  PFIZER   Organization/00394544000851
# 373698                  PFIZER   Organization/00394544000851
# 373699        SINOVAC/BUTANTAN              Organization/152
# 373700     ASTRAZENECA/FIOCRUZ   Organization/33781055000135
# 373701                  PFIZER            Organization/28290
#
#        vacina_dataAplicacao vacina_descricao_dose  vacina_codigo  \
# 0                2021-07-28               1ª Dose             99
# 1                2022-02-04               1ª Dose             99
# 2                2021-06-02               1ª Dose             89
# 3                2022-08-02               Reforço             85
# 4                2021-05-15               1ª Dose             85
# ...                     ...                   ...            ...
# 373697           2021-08-11               1ª Dose             87
# 373698           2021-09-21               2ª Dose             87
# 373699           2022-03-05               1ª Dose             86
# 373700           2021-07-19               1ª Dose             85
# 373701           2021-12-13               2ª Dose             87
#
#                                       vacina_nome sistema_origem
# 0          COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 1          COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 2                COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 3       COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 4       COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# ...                                           ...            ...
# 373697                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 373698                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 373699      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 373700  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 373701                COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [373702 rows x 32 columns]

# %%
vacAcre.head()
# Out:
#                                  document_id  \
# 0  ae60a3c3-b038-46ad-8bcc-b0fbb85591c0-i0b0
# 1  a185d13a-5619-41ab-9dcc-fc05c222c556-i0b0
# 2  ae4eb2f2-de1e-431d-b09d-b1d2a310eb7c-i0b0
# 3  a1ad2a49-e8d4-4c3d-99e4-dcf4d46e45f9-i0b0
# 4  dcf75e5a-fd0f-4cc6-bb98-36c958e156da-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  edf77236d644ba7d0049cf916e5dfdec81910c06fadc69...               9
# 1  53a21b19090e69145108f97de5a72610db1b1383b99147...              11
# 2  ae5f5c4633ba030bc700f8f5410a01167a54b4ed740729...              43
# 3  ede2ec24eae3e257b9acb6c57f8651c60e0d016aeb8c00...              29
# 4  5aafa70333fc3942d6b51c6bd586cd64bec8103f44c0a5...              47
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2011-08-31                          M                        3
# 1              2010-02-05                          F                        4
# 2              1978-04-22                          M                        4
# 3              1992-12-21                          M                        3
# 4              1974-04-16                          F                        4
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0                  PARDA                           120040.0
# 1                AMARELA                           120040.0
# 2                AMARELA                           120040.0
# 3                  PARDA                           120040.0
# 4                AMARELA                           120035.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                    RIO BRANCO  ...
# 1                      10.0                    RIO BRANCO  ...
# 2                      10.0                    RIO BRANCO  ...
# 3                      10.0                    RIO BRANCO  ...
# 4                      10.0          MARECHAL THAUMATURGO  ...
#
#   vacina_categoria_codigo             vacina_categoria_nome   vacina_lote  \
# 0                     NaN                               NaN        FP8290
# 1                     NaN                               NaN        FP8290
# 2                    10.0       Trabalhadores de Transporte       ABW4731
# 3                     2.0                      Faixa Etária    221VCD025W
# 4                     6.0  Povos e Comunidades Tradicionais  212VCD001ZVB
#
#    vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0  Pendente Identificação            Organization/28290           2021-07-28
# 1  Pendente Identificação            Organization/28290           2022-02-04
# 2             ASTRAZENECA   Organization/00394544000851           2021-06-02
# 3     ASTRAZENECA/FIOCRUZ                           149           2022-08-02
# 4     ASTRAZENECA/FIOCRUZ   Organization/33781055000135           2021-05-15
#
#   vacina_descricao_dose  vacina_codigo  \
# 0               1ª Dose             99
# 1               1ª Dose             99
# 2               1ª Dose             89
# 3               Reforço             85
# 4               1ª Dose             85
#
#                                  vacina_nome sistema_origem
# 0     COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 1     COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 2           COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 3  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 4  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Verificando dataframe

# %%
vacAcre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373702 entries, 0 to 373701
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               373702 non-null  object
#  1   paciente_id                               373702 non-null  object
#  2   paciente_idade                            373702 non-null  int64
#  3   paciente_dataNascimento                   373702 non-null  object
#  4   paciente_enumSexoBiologico                373702 non-null  object
#  5   paciente_racaCor_codigo                   373702 non-null  int64
#  6   paciente_racaCor_valor                    373702 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         371391 non-null  float64
#  8   paciente_endereco_coPais                  371397 non-null  float64
#  9   paciente_endereco_nmMunicipio             371396 non-null  object
#  10  paciente_endereco_nmPais                  371397 non-null  object
#  11  paciente_endereco_uf                      371391 non-null  object
#  12  paciente_endereco_cep                     319165 non-null  float64
#  13  paciente_nacionalidade_enumNacionalidade  373524 non-null  object
#  14  estabelecimento_valor                     373702 non-null  int64
#  15  estabelecimento_razaoSocial               373702 non-null  object
#  16  estalecimento_noFantasia                  373702 non-null  object
#  17  estabelecimento_municipio_codigo          373702 non-null  int64
#  18  estabelecimento_municipio_nome            373702 non-null  object
#  19  estabelecimento_uf                        373702 non-null  object
#  20  vacina_grupoAtendimento_codigo            373702 non-null  int64
#  21  vacina_grupoAtendimento_nome              372736 non-null  object
#  22  vacina_categoria_codigo                   353347 non-null  float64
#  23  vacina_categoria_nome                     353347 non-null  object
#  24  vacina_lote                               373702 non-null  object
#  25  vacina_fabricante_nome                    373702 non-null  object
#  26  vacina_fabricante_referencia              371562 non-null  object
#  27  vacina_dataAplicacao                      373702 non-null  object
#  28  vacina_descricao_dose                     373702 non-null  object
#  29  vacina_codigo                             373702 non-null  int64
#  30  vacina_nome                               373693 non-null  object
#  31  sistema_origem                            373303 non-null  object
# dtypes: float64(4), int64(6), object(22)
# memory usage: 91.2+ MB

# %% [markdown]
# ## Copiando parte do dataframe

# %%
vacAcre_copy = vacAcre[:20000].copy()
vacAcre_copy
# Out:
#                                      document_id  \
# 0      ae60a3c3-b038-46ad-8bcc-b0fbb85591c0-i0b0
# 1      a185d13a-5619-41ab-9dcc-fc05c222c556-i0b0
# 2      ae4eb2f2-de1e-431d-b09d-b1d2a310eb7c-i0b0
# 3      a1ad2a49-e8d4-4c3d-99e4-dcf4d46e45f9-i0b0
# 4      dcf75e5a-fd0f-4cc6-bb98-36c958e156da-i0b0
# ...                                          ...
# 19995  41329740-7cd0-4a81-af02-46dc368a69c4-i0b0
# 19996  db6f5fc4-188a-4d94-be5c-0110493e0c86-i0b0
# 19997  424e990f-d905-45ba-a093-104785978b16-i0b0
# 19998  f09a9131-eac7-46bb-b9c2-aa139d2ecac5-i0b0
# 19999  e223da9c-6d86-4190-8a8a-c2d1cd19066c-i0b0
#
#                                              paciente_id  paciente_idade  \
# 0      edf77236d644ba7d0049cf916e5dfdec81910c06fadc69...               9
# 1      53a21b19090e69145108f97de5a72610db1b1383b99147...              11
# 2      ae5f5c4633ba030bc700f8f5410a01167a54b4ed740729...              43
# 3      ede2ec24eae3e257b9acb6c57f8651c60e0d016aeb8c00...              29
# 4      5aafa70333fc3942d6b51c6bd586cd64bec8103f44c0a5...              47
# ...                                                  ...             ...
# 19995  6fc759e270e2e4638d75a75ee1c7dd47514242f626a35e...              62
# 19996  d9c460626c7ea743ac54dceffc4f1e47c9b832c1d1a982...              23
# 19997  d205ee95b341c6536bf677fc1888a87717148d5b9ee701...              23
# 19998  a082fa6aa0c1b3011728664d54b899d9f292785eedee4c...              33
# 19999  e38020a35ae2f604fce91afd10fc195f843a9c70d74a36...              33
#
#       paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                  2011-08-31                          M
# 1                  2010-02-05                          F
# 2                  1978-04-22                          M
# 3                  1992-12-21                          M
# 4                  1974-04-16                          F
# ...                       ...                        ...
# 19995              1959-09-06                          M
# 19996              1999-01-25                          M
# 19997              1998-04-11                          M
# 19998              1987-10-14                          M
# 19999              1988-07-23                          F
#
#        paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                            3                  PARDA
# 1                            4                AMARELA
# 2                            4                AMARELA
# 3                            3                  PARDA
# 4                            4                AMARELA
# ...                        ...                    ...
# 19995                        4                AMARELA
# 19996                        4                AMARELA
# 19997                       99         SEM INFORMACAO
# 19998                        3                  PARDA
# 19999                        3                  PARDA
#
#        paciente_endereco_coIbgeMunicipio  paciente_endereco_coPais  \
# 0                               120040.0                      10.0
# 1                               120040.0                      10.0
# 2                               120040.0                      10.0
# 3                               120040.0                      10.0
# 4                               120035.0                      10.0
# ...                                  ...                       ...
# 19995                           120025.0                      10.0
# 19996                           120070.0                      10.0
# 19997                           120080.0                      10.0
# 19998                           120040.0                      10.0
# 19999                           120050.0                      10.0
#
#       paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                        RIO BRANCO  ...                     NaN
# 1                        RIO BRANCO  ...                     NaN
# 2                        RIO BRANCO  ...                    10.0
# 3                        RIO BRANCO  ...                     2.0
# 4              MARECHAL THAUMATURGO  ...                     6.0
# ...                             ...  ...                     ...
# 19995                EPITACIOLANDIA  ...                     2.0
# 19996                        XAPURI  ...                     2.0
# 19997                    PORTO ACRE  ...                     2.0
# 19998                    RIO BRANCO  ...                     2.0
# 19999                SENA MADUREIRA  ...                     2.0
#
#                   vacina_categoria_nome   vacina_lote  vacina_fabricante_nome  \
# 0                                   NaN        FP8290  Pendente Identificação
# 1                                   NaN        FP8290  Pendente Identificação
# 2           Trabalhadores de Transporte       ABW4731             ASTRAZENECA
# 3                          Faixa Etária    221VCD025W     ASTRAZENECA/FIOCRUZ
# 4      Povos e Comunidades Tradicionais  212VCD001ZVB     ASTRAZENECA/FIOCRUZ
# ...                                 ...           ...                     ...
# 19995                      Faixa Etária        202001                  PFIZER
# 19996                      Faixa Etária    B202106081  Pendente Identificação
# 19997                      Faixa Etária        210277        SINOVAC/BUTANTAN
# 19998                      Faixa Etária        FA9096                  PFIZER
# 19999                      Faixa Etária    21OVCD317W     ASTRAZENECA/FIOCRUZ
#
#        vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                Organization/28290           2021-07-28
# 1                Organization/28290           2022-02-04
# 2       Organization/00394544000851           2021-06-02
# 3                               149           2022-08-02
# 4       Organization/33781055000135           2021-05-15
# ...                             ...                  ...
# 19995                         28290           2022-08-20
# 19996            Organization/29501           2022-03-07
# 19997   Organization/61189445000156           2021-07-14
# 19998   Organization/00394544000851           2021-07-23
# 19999                           149           2022-06-27
#
#       vacina_descricao_dose  vacina_codigo  \
# 0                   1ª Dose             99
# 1                   1ª Dose             99
# 2                   1ª Dose             89
# 3                   Reforço             85
# 4                   1ª Dose             85
# ...                     ...            ...
# 19995               Reforço             87
# 19996               2ª Dose             98
# 19997               1ª Dose             86
# 19998               1ª Dose             87
# 19999               2ª Dose             85
#
#                                      vacina_nome sistema_origem
# 0         COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 1         COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 2               COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 3      COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 4      COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# ...                                          ...            ...
# 19995                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 19996               COVID-19 SINOVAC - CORONAVAC       Novo PNI
# 19997      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 19998                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 19999  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
#
# [20000 rows x 32 columns]

# %% [markdown]
# ## Qual o percentual das vacinas aplicadas foram na capital???

# %%
vacAcre_copy['fl_capital'] = 0

# %%
vacAcre_copy.head(2)
# Out:
#                                  document_id  \
# 0  ae60a3c3-b038-46ad-8bcc-b0fbb85591c0-i0b0
# 1  a185d13a-5619-41ab-9dcc-fc05c222c556-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  edf77236d644ba7d0049cf916e5dfdec81910c06fadc69...               9
# 1  53a21b19090e69145108f97de5a72610db1b1383b99147...              11
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2011-08-31                          M                        3
# 1              2010-02-05                          F                        4
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0                  PARDA                           120040.0
# 1                AMARELA                           120040.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                    RIO BRANCO  ...
# 1                      10.0                    RIO BRANCO  ...
#
#   vacina_categoria_nome vacina_lote  vacina_fabricante_nome  \
# 0                   NaN      FP8290  Pendente Identificação
# 1                   NaN      FP8290  Pendente Identificação
#
#   vacina_fabricante_referencia  vacina_dataAplicacao vacina_descricao_dose  \
# 0           Organization/28290            2021-07-28               1ª Dose
# 1           Organization/28290            2022-02-04               1ª Dose
#
#   vacina_codigo                             vacina_nome sistema_origem  \
# 0            99  COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 1            99  COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
#
#   fl_capital
# 0          0
# 1          0
#
# [2 rows x 33 columns]

# %%
vacAcre_copy.loc[vacAcre_copy['paciente_endereco_nmMunicipio'] == 'RIO BRANCO', 'fl_capital'] = 1

# %%
vacAcre_copy.head(10)
# Out:
#                                  document_id  \
# 0  ae60a3c3-b038-46ad-8bcc-b0fbb85591c0-i0b0
# 1  a185d13a-5619-41ab-9dcc-fc05c222c556-i0b0
# 2  ae4eb2f2-de1e-431d-b09d-b1d2a310eb7c-i0b0
# 3  a1ad2a49-e8d4-4c3d-99e4-dcf4d46e45f9-i0b0
# 4  dcf75e5a-fd0f-4cc6-bb98-36c958e156da-i0b0
# 5  a1c5e6e3-c3c3-4453-bb08-2dfda43ba763-i0b0
# 6  e5edb5a9-cd5a-4d8a-817e-b5ab3bade287-i0b0
# 7  a1fbb330-d153-4b71-aa8c-71e0c5e777f8-i0b0
# 8  520198e4-bfdb-486c-80bd-3a2526bfd68b-i0b0
# 9  a221c9aa-ffb7-4013-be45-c67ed78d90dd-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  edf77236d644ba7d0049cf916e5dfdec81910c06fadc69...               9
# 1  53a21b19090e69145108f97de5a72610db1b1383b99147...              11
# 2  ae5f5c4633ba030bc700f8f5410a01167a54b4ed740729...              43
# 3  ede2ec24eae3e257b9acb6c57f8651c60e0d016aeb8c00...              29
# 4  5aafa70333fc3942d6b51c6bd586cd64bec8103f44c0a5...              47
# 5  987999d0770c504a23f50f985816eb54fa35cd32b4d815...              87
# 6  62b48f7b11b372943cc9429232a1716a8b31ce72542b1f...              73
# 7  91cc2369c863cd1c4e79cdf5db0f75c7c6900aee7aaeaf...              21
# 8  a5a9f3c5bbc1befa625cff13b1ae0ed7fd2cb0c57dcf09...              10
# 9  d7d61b6dbf577ba3d94c65df43a5e047645464f9788630...              21
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2011-08-31                          M                        3
# 1              2010-02-05                          F                        4
# 2              1978-04-22                          M                        4
# 3              1992-12-21                          M                        3
# 4              1974-04-16                          F                        4
# 5              1933-07-18                          F                        4
# 6              1950-09-13                          M                        4
# 7              2000-07-18                          F                        3
# 8              2012-02-11                          F                       99
# 9              1999-08-31                          M                        3
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0                  PARDA                           120040.0
# 1                AMARELA                           120040.0
# 2                AMARELA                           120040.0
# 3                  PARDA                           120040.0
# 4                AMARELA                           120035.0
# 5                AMARELA                           120050.0
# 6                AMARELA                           120030.0
# 7                  PARDA                           120050.0
# 8         SEM INFORMACAO                           120038.0
# 9                  PARDA                           120040.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                    RIO BRANCO  ...
# 1                      10.0                    RIO BRANCO  ...
# 2                      10.0                    RIO BRANCO  ...
# 3                      10.0                    RIO BRANCO  ...
# 4                      10.0          MARECHAL THAUMATURGO  ...
# 5                      10.0                SENA MADUREIRA  ...
# 6                      10.0                         FEIJO  ...
# 7                      10.0                SENA MADUREIRA  ...
# 8                      10.0             PLACIDO DE CASTRO  ...
# 9                      10.0                    RIO BRANCO  ...
#
#               vacina_categoria_nome   vacina_lote  vacina_fabricante_nome  \
# 0                               NaN        FP8290  Pendente Identificação
# 1                               NaN        FP8290  Pendente Identificação
# 2       Trabalhadores de Transporte       ABW4731             ASTRAZENECA
# 3                      Faixa Etária    221VCD025W     ASTRAZENECA/FIOCRUZ
# 4  Povos e Comunidades Tradicionais  212VCD001ZVB     ASTRAZENECA/FIOCRUZ
# 5  Povos e Comunidades Tradicionais  212VCD001ZVB     ASTRAZENECA/FIOCRUZ
# 6                      Faixa Etária        GJ2631                  PFIZER
# 7                      Faixa Etária        210198             ASTRAZENECA
# 8                               NaN        210520        SINOVAC/BUTANTAN
# 9                      Faixa Etária        FA9096                  PFIZER
#
#   vacina_fabricante_referencia  vacina_dataAplicacao vacina_descricao_dose  \
# 0           Organization/28290            2021-07-28               1ª Dose
# 1           Organization/28290            2022-02-04               1ª Dose
# 2  Organization/00394544000851            2021-06-02               1ª Dose
# 3                          149            2022-08-02               Reforço
# 4  Organization/33781055000135            2021-05-15               1ª Dose
# 5  Organization/33781055000135            2021-04-14               1ª Dose
# 6                        28290            2023-11-27               Reforço
# 7  Organization/00394544000851            2021-08-10               2ª Dose
# 8                        29501            2022-09-13               2ª Dose
# 9  Organization/00394544000851            2021-07-23               1ª Dose
#
#   vacina_codigo                                vacina_nome sistema_origem  \
# 0            99     COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 1            99     COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 2            89           COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 3            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 4            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 5            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 6           103      COVID-19 PFIZER - COMIRNATY BIVALENTE       Novo PNI
# 7            89           COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 8            86      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 9            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
#
#   fl_capital
# 0          1
# 1          1
# 2          1
# 3          1
# 4          0
# 5          0
# 6          0
# 7          0
# 8          0
# 9          1
#
# [10 rows x 33 columns]

# %%
vacAcre_copy[['paciente_endereco_nmMunicipio','fl_capital']]
# Out:
#       paciente_endereco_nmMunicipio  fl_capital
# 0                        RIO BRANCO           1
# 1                        RIO BRANCO           1
# 2                        RIO BRANCO           1
# 3                        RIO BRANCO           1
# 4              MARECHAL THAUMATURGO           0
# ...                             ...         ...
# 19995                EPITACIOLANDIA           0
# 19996                        XAPURI           0
# 19997                    PORTO ACRE           0
# 19998                    RIO BRANCO           1
# 19999                SENA MADUREIRA           0
#
# [20000 rows x 2 columns]

# %%
vacAcre_copy['fl_capital'].sum()
# Out:
# 9889

# %%
9889/20000
# Out:
# 0.49445

# %% [markdown]
# ## Qual a idade média dos pacientes???

# %%
vacAcre_copy['paciente_idade'].mean()
# Out:
# 36.3288
